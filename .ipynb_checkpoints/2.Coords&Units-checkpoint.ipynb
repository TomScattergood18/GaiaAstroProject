# %% [markdown]
# In this lesson, we'll pick up where we left off and write a query to select stars from a particular region of the sky.

# %%
# Imports
import sys
import astropy.units as u
import astropy.coordinates as coord
from astroquery.gaia import Gaia
from astropy.coordinates import SkyCoord
import numpy as np
from astropy.coordinates import frame_transform_graph
# Out:
# Warning: the passwords of all user accounts have been inactivated.              Please visit https://cas.cosmos.esa.int/cas/passwd to set a new one. Workaround solutions for the Gaia Archive issues following the infrastructure upgrade: https://www.cosmos.esa.int/web/gaia/news#WorkaroundArchive

# %% [markdown]
# Outline:
# We'll start with an example that does a "cone search"; that is, it selects stars that appear in a circular region of the sky.
#
# Then, to select stars in the vicinity of GD-1, we'll:
#
# Use Quantity objects to represent measurements with units.
#
# Use Astropy to convert coordinates from one frame to another.
#
# Use the ADQL keywords POLYGON, CONTAINS, and POINT to select stars that fall within a polygonal region.
#
# Submit a query and download the results.
#
# Store the results in a FITS file.

# %% [markdown]
# Cannot install gala package used for GD-1, so instead we create a class of the same frame

# %% [markdown]
# Working with units:
#
# Astropy provides tools for including units explicitly in computations, which makes it possible to detect errors before they cause disasters.

# %%
angle = 10 * u.degree
type(angle)
angle
# Out:
# <Quantity 10. deg>

# %%
# Convert degrees to arcminutes
angle_arcmin = angle.to(u.arcmin)
angle_arcmin
# Out:
# <Quantity 600. arcmin>

# %%
# If you add quantities, Astropy converts them to compatible units if possible
angle + 30*u.arcmin
# Out:
# <Quantity 10.5 deg>

# %%
# If units are not compatible
#angle + 5*u.second # UnitConversionError

# %% [markdown]
# Excercise:
#
# Create a quantity that represents 5 arcminutes and assign it to a variable called radius.
#
# Then convert it to degrees.

# %%
radius = 5*u.arcmin
radius
# Out:
# <Quantity 5. arcmin>

# %%
radius.to(u.degree)
# Out:
# <Quantity 0.08333333 deg>

# %% [markdown]
# Selecting a region:
#
# One of the most common ways to restrict a query is to select stars in a particular region of the sky
#
# Here's a query from the Gaia archive documentation that selects objects in a circular region centered at (88.8, 7.4) with a search radius of 5 arcmin (0.08333 deg).

# %%
query_cone = """
SELECT TOP 10
source_id
FROM gaiadr2.gaia_source
WHERE 1=CONTAINS(
    POINT(ra,dec),
    CIRCLE(88.8, 7.4, 0.083333))
"""

# POINT, CIRCLE, and CONTAINS are specific to ADQL

# %% [markdown]
# POINT: a location in ICRS coordinates, specified in degrees of right ascension and declination.
#
# CIRCLE: a circle where the first two values are the coordinates of the center and the third is the radius in degrees.
#
# CONTAINS: a function that returns 1 if a POINT is contained in a shape and 0 otherwise.

# %%
job = Gaia.launch_job(query_cone)
job

# %%
results = job.get_results()
results
# Out:
# <Table length=10>
#      source_id
#        int64
# -------------------
# 3322773857683389824
# 3322774411734159872
# 3322774102495009024
# 3322774136855272704
# 3322774617893037568
# 3322774652249784192
# 3322774102494023424
# 3322774102494024320
# 3322773720244239232
# 3322774514810857216

# %% [markdown]
# Excercise:
#
# You can use TOP to limit the size of the results, but then you still don't know how big the results will be
#
# An alternative is to use COUNT, which asks for the number of rows that would be selected, but it does not return them.
#
# In the previous query, replace TOP 10 source_id with COUNT(source_id) and run the query again. How many stars has Gaia identified in the cone we searched?

# %%
query_cone = """
SELECT 
COUNT(source_id)
FROM gaiadr2.gaia_source
WHERE 1=CONTAINS(
    POINT(ra,dec),
    CIRCLE(88.8, 7.4, 0.083333))
"""

job = Gaia.launch_job(query_cone)
results = job.get_results()
results
# Out:
# <Table length=1>
# COUNT
# int64
# -----
#   594

# %% [markdown]
# Answer: 594 stars

# %% [markdown]
# Getting GD-1 Data

# %% [markdown]
# # Attempting to reproduce figure 1 from the paper
#
# Transforming coordinates:
#
# Astropy provides a SkyCoord object that represents sky coordinatyes relative to a specified frame

# %%
from IPython.display import Image
Image(filename='gd1-4.png')

# %%
# Creating a SkyCoord object that represents
# the apporx coordinates of Betelgeuse in the ICRS frame

ra = 88.8 * u.degree
dec = 7.4 * u.degree

coord_icrs = SkyCoord(ra=ra, dec=dec, frame="icrs")
coord_icrs
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (88.8, 7.4)>

# %% [markdown]
# We can transform coord_icrs to galactic coordinates:

# %%
coord_galactic = coord_icrs.transform_to("galactic")
coord_galactic
# Out:
# <SkyCoord (Galactic): (l, b) in deg
#     (199.79693102, -8.95591653)>

# %% [markdown]
# To transform to and from GD-1 coordinates, we'll use a framed defined by Gala (an Astropy affiliated library that provides tools for galactic dynamics). We could not install gala, so we will instead refer to the created class earlier in this notebook: GD1Koposov10(). This class is identical to the gala import

# %%
import GD1Koposov10
gd1_frame = GD1Koposov10.GD1Koposov10()
gd1_frame
# Out:
# <GD1Koposov10 Frame>

# %% [markdown]
# We can use it to find the coordinates of Betelgeuse in the GD-1 frame, like this:

# %%
coord_gd1 = coord_icrs.transform_to(gd1_frame)
coord_gd1
# Out:
# <SkyCoord (GD1Koposov10): (phi1, phi2) in deg
#     (-94.97222038, 34.5813813)>

# %% [markdown]
# The coordinates are called phi1 and phi2 (the same coordinates shown in the figure from the paper we are trying to replicate)

# %% [markdown]
# # Excercise
# Find the locaiton of  GD-1 in ICRS coordinates:

# %%
# Create a SkyCoord object at 0°, 0° in the GD-1 frame.
phi1 = 0*u.degree
phi2 = 0*u.degree

gd1_skycoord = SkyCoord(phi1=phi1, phi2=phi2, frame=gd1_frame)
gd1_skycoord
# Out:
# <SkyCoord (GD1Koposov10): (phi1, phi2) in deg
#     (0., 0.)>

# %%
#Transform it to the ICRS frame.
gd1_skycoord.transform_to('icrs')
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (200., 59.4504341)>

# %% [raw]
# Selecting a rectangle
#
# Now we'll use these coord transformations to define a rectangle in the GD-1 frame and transform it to ICRS

# %%
phi1_min = -55 *u.degree
phi1_max = -45 *u.degree
phi2_min = -8 *u.degree
phi2_max = 4 *u.degree

# %%
def make_rectangle(xmin, xmax, ymin,ymax):
    """
    Function that returns the corners of a rectangle
    Returns a tuple containing a  in phi1 
        followed by a list of coordinates in phi2
    """
    xs = [xmin, xmin, xmax, xmax, xmin]
    ys = [ymin, ymax, ymax, ymin, ymin]
    return xs, ys

# %%
phi1_rect, phi2_rect = make_rectangle(phi1_min, phi1_max,
                                     phi2_min, phi2_max)

# %% [markdown]
# In order to use these GD1-frame corner coordinates in a Gaia query, we must convert them to ICRS

# %%
# Step 1: Create a SkyCoord object
corners = SkyCoord(phi1=phi1_rect, phi2=phi2_rect, frame=gd1_frame)
corners
# Out:
# <SkyCoord (GD1Koposov10): (phi1, phi2) in deg
#     [(-55., -8.), (-55.,  4.), (-45.,  4.), (-45., -8.), (-55., -8.)]>

# %%
# Step 2: Transform corners into ICRS coordinates
corners_icrs = corners.transform_to("icrs") 
corners_icrs
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     [(146.27533314, 19.26190982), (135.42163944, 25.87738723),
#      (141.60264825, 34.3048303 ), (152.81671045, 27.13611254),
#      (146.27533314, 19.26190982)]>

# %% [markdown]
# The result is actually a non-rectangular polygon
#
# To use this polygon in an ADQL query, we have to convert it to a string with a comma-separated list of coordinates

# %%
def skycoord_to_string(skycoord):
    t = corners_icrs.to_string()
    s = " ".join(t)
    return s.replace(" ", ",")

# %%
point_list = skycoord_to_string(corners_icrs)
point_list
# Out:
# '146.275,19.2619,135.422,25.8774,141.603,34.3048,152.817,27.1361,146.275,19.2619'

# %% [markdown]
# # Assembling the query

# %%
columns = "source_id, ra, dec, pmra, pmdec, parallax"

query_base = """
SELECT TOP 10
{columns}
FROM gaiadr2.gaia_source
WHERE parallax < 1
    AND bp_rp BETWEEN -0.75 AND 2
    AND 1 = CONTAINS(POINT(ra, dec),
                     POLYGON({point_list}))
"""

# %%
query = query_base.format(columns=columns, point_list=point_list)
print(query)
# Out:
# SELECT TOP 10
# source_id, ra, dec, pmra, pmdec, parallax
# FROM gaiadr2.gaia_source
# WHERE parallax < 1
#     AND bp_rp BETWEEN -0.75 AND 2
#     AND 1 = CONTAINS(POINT(ra, dec),
#                      POLYGON(146.275,19.2619,135.422,25.8774,141.603,34.3048,152.817,27.1361,146.275,19.2619))

# %%
job = Gaia.launch_job_async(query)
print(job)
# Out:
# INFO: Query finished. [astroquery.utils.tap.core]
# <Table length=10>
#    name    dtype    unit                              description
# --------- ------- -------- ------------------------------------------------------------------
# source_id   int64          Unique source identifier (unique within a particular Data Release)
#        ra float64      deg                                                    Right ascension
#       dec float64      deg                                                        Declination
#      pmra float64 mas / yr                         Proper motion in right ascension direction
#     pmdec float64 mas / yr                             Proper motion in declination direction
#  parallax float64      mas                                                           Parallax
# Jobid: 0ed92835-118d-11f1-b8e9-bc97e148b76b-O
# Phase: COMPLETED
# Owner: None
# Output file: async_20260224142816.vot
# Results: None

# %%
results = job.get_results()
results
# Out:
# <Table length=10>
#     source_id              ra         ...       parallax
#                           deg         ...         mas
#       int64             float64       ...       float64
# ------------------ ------------------ ... -------------------
# 644580518461269632 144.96079381729163 ...   -9.57726711068798
# 797151496416964992 143.46563444398694 ...  -7.887848893590391
# 642321223929438976 149.13266779468913 ...  -7.192315806159905
# 698229191178802688 138.57658337767324 ... -6.7219918967714465
# 647782983516066048 144.19560717192726 ...  -6.668660908047409
# 646580938135173888 145.44633513907803 ...  -6.638708900521216
# 642143206125239808 147.99036614830604 ...  -6.518372731135347
# 644351472152318976 142.96957552055088 ...  -6.220639593313612
# 698253689672318720 138.78811266329714 ...  -6.203123794739136
# 700958183335130752 141.74003938073994 ...  -6.191379013077969

# %% [markdown]
# now that we know the query works, we can remove TOP 10 from the query to return all the data

# %%
query_base = """
SELECT
{columns}
FROM gaiadr2.gaia_source
WHERE parallax < 1
    AND bp_rp BETWEEN -0.75 AND 2
    AND 1 = CONTAINS(POINT(ra, dec),
                     POLYGON({point_list}))
"""

# %%
query = query_base.format(columns=columns, point_list=point_list)
job = Gaia.launch_job_async(query)
# Out:
# INFO: Query finished. [astroquery.utils.tap.core]

# %%
results = job.get_results()
results
# Out:
# <Table length=140339>
#     source_id              ra         ...       parallax
#                           deg         ...         mas
#       int64             float64       ...       float64
# ------------------ ------------------ ... --------------------
# 638249388774300416 141.93501729008403 ...   0.0956975204679928
# 638249526213253504  141.9753061718924 ...   0.9107815912221747
# 638042856682365312 142.60877152027857 ...   0.1413405186597264
# 638330305958410880 141.86014647492885 ...  0.29564149985564947
# 638247808226333824 142.06685526516077 ...  0.37008934654368597
# 638040962601437952 142.43297107446548 ...   0.3953942905076676
# 638021721148028032  142.7734865975511 ...   0.7548992385125219
# 638057798874006272 142.22333117472294 ...   0.5499980977288826
# 638008114691528576 143.21984737101306 ...  0.20947378699746502
#                ...                ... ...                  ...
# 634882237494099456 143.62387059511335 ... -0.21184748229399245
# 634695393531773824 144.04988046736443 ...   0.5557838934855736
# 634986450581899904 143.53647845048522 ...  -0.8090954731559972
# 634904983640919552  143.9429937350832 ...  0.23909872095075443
# 634696488748234752 144.01723312202643 ... -0.17747508598872058
# 634907732419474560 143.67898719198124 ...   0.6651807996511412
# 634990023993097344 143.25237782667767 ...   0.8876542742738688
# 634935430663403904  143.7938453770193 ... -0.28773072514270237
# 635004386363326848  143.3273570298204 ...   0.5630250079523722

# %% [markdown]
# This is a large dataset (over 140,000 stars in this polygon), we will want to save it instead of having to query GAIA again
#
# Astropy Table objects provide the write method, which allows us to write the table to disk

# %%
filename = "gd1_results.fits"
results.write(filename, overwrite=True)
# FITS format preserves the metadata associated with the table

# %%
from os.path import getsize

MB = 1024*1024
getsize(filename) / MB
# Out:
# 6.4324951171875
